# %%
"""
Convert bird list to scientific name ~done
Get folders from /datasets/xeno_canto/audio to /datasets/xeno_canto/491_dataset
Change folder names to bird code

"""
# Out:
# '\nConvert bird list to scientific name ~done\nGet folders from /datasets/xeno_canto/audio to /datasets/xeno_canto/491_dataset\nChange folder names to bird code\n\n'

# %%
import os
import pandas as pd
import json

# %%
xc_audio = '/datasets/xeno_canto/audio/'
xc_metadata = '/datasets/xeno_canto/metadata/'
dest_audio = '/datasets/xeno_canto/491_dataset/'

bird_list_path = '../../assets/combined_scientific_named_list.txt'
ebird_codes_path = '../../assets/eBird_Taxonomy_v2021.csv'
data = '../dataset/metadata/metadata.csv'

# %%
dest_sm = '/datasets/xeno_canto/sm_dataset/'
sm_dirs = os.listdir(dest_audio)

# %%
sm_dirs = sm_dirs[0:20]

# %%
all_count = 0
for dirs in sm_dirs:
    all_count += len(os.listdir(dest_audio + dirs))

# %%
df = pd.read_csv(data)
df2 = pd.DataFrame()

# %%
for el in sm_dirs:
    entry = df.loc[df['primary_label'] == el]
    df2 = df2.append(entry)

# %%
l = os.listdir(dest_sm)

# %%
def change_name(x):
    f = x.split('/')
    x = f[1]
    return x

# %%
df2['filename'] = df2['filename'].apply(change_name)

# %%
for i, row in df2.iterrows():
    if not row['filename'] in l:
        df2 = df2.drop(i)

# %%
df2.to_csv('../dataset/metadata/sm_meta.csv', index = False)

# %%
#Create metadata
output_list = []
for bird in bird_list:
        if bird in all_meta:
            for json_file in os.listdir(xc_metadata + bird):
                
                with open(xc_metadata + bird + '/' + json_file, "rb") as infile:
                    load_file = json.load(infile)
                    rec_dict = load_file['recordings']
            
                for elem in rec_dict:
                    elem['primary_label'] = get_bird_code(bird)
                    elem['secondary_label'] = elem['also']
                    elem['latitude']= elem['lat']
                    elem['longitude']= elem['lng']
                    elem['scientific_name'] = elem['gen'] + ' ' + elem['sp']
                    elem['common_name'] = elem['en']
                    idd = elem['id'] #not include
                    file = 'XC{ids}.ogg'.format(ids = idd) #not include
                    elem['filename'] = bird + '/' + file
                    del elem['gen']
                    del elem['sp']
                    del elem['ssp']
                    del elem['cnt']
                    del elem['loc']
                    del elem['rmk']
                    del elem['also']
                    del elem['en']
                    del elem['lat']
                    del elem['lng']
                    output_list.append(elem)
# Out:
#        primary_label                         secondary_label  \
# 0            lesred1                                    ['']
# 1            lesred1                                    ['']
# 2            lesred1                                    ['']
# 3            lesred1                                    ['']
# 4            lesred1                                    ['']
# ...              ...                                     ...
# 271748        norlap  ['Alauda arvensis', 'Sylvia communis']
# 271749        norlap                                    ['']
# 271750        norlap                                    ['']
# 271751        norlap                                    ['']
# 271752        norlap                           ['Crex crex']
#
#                                          type  latitude  longitude  \
# 0                                 flight call   51.4812    -9.7785
# 1                                 flight call   53.7276    -7.7933
# 2                                 flight call   53.7276    -7.7933
# 3                                 flight call   53.7276    -7.7933
# 4                                 flight call   53.7276    -7.7933
# ...                                       ...       ...        ...
# 271748                             alarm call   54.1359    -0.5537
# 271749                            flight call   54.1338    -0.5523
# 271750                                   call   54.1200    -0.5445
# 271751                                   call   54.1200    -0.5445
# 271752  alarm call, female, flight call, male   56.5655    47.1698
#
#           scientific_name       common_name   time                      url  \
# 0        Acanthis cabaret    Lesser Redpoll  08:00  //xeno-canto.org/693048
# 1        Acanthis cabaret    Lesser Redpoll  11:00  //xeno-canto.org/692820
# 2        Acanthis cabaret    Lesser Redpoll  11:00  //xeno-canto.org/692819
# 3        Acanthis cabaret    Lesser Redpoll  11:00  //xeno-canto.org/692818
# 4        Acanthis cabaret    Lesser Redpoll  11:00  //xeno-canto.org/692817
# ...                   ...               ...    ...                      ...
# 271748  Vanellus vanellus  Northern Lapwing  06:42  //xeno-canto.org/321186
# 271749  Vanellus vanellus  Northern Lapwing  08:37  //xeno-canto.org/296869
# 271750  Vanellus vanellus  Northern Lapwing  08:24  //xeno-canto.org/208193
# 271751  Vanellus vanellus  Northern Lapwing  08:22  //xeno-canto.org/208191
# 271752  Vanellus vanellus  Northern Lapwing  05:30  //xeno-canto.org/134665
#
#                   filename  q
# 0       lesred1/693048.wav  A
# 1       lesred1/692820.wav  A
# 2       lesred1/692819.wav  A
# 3       lesred1/692818.wav  A
# 4       lesred1/692817.wav  A
# ...                    ... ..
# 271748   norlap/321186.wav  E
# 271749   norlap/296869.wav  E
# 271750   norlap/208193.wav  E
# 271751   norlap/208191.wav  E
# 271752   norlap/134665.wav  E
#
# [271753 rows x 11 columns]

# %%
all_audio = os.listdir(xc_audio)
all_meta = os.listdir(xc_metadata)


bird_list = []
with open(bird_list_path, 'r') as blist:
    temp = blist.readlines()
    bird_list = [f.replace('\n', '') for f in temp]
    bird_list.sort()

df = pd.read_csv(ebird_codes_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_196256/726190356.py in <module>
#       4
#       5 bird_list = []
# ----> 6 with open(bird_list_path, 'r') as blist:
#       7     temp = blist.readlines()
#       8     bird_list = [f.replace('\n', '') for f in temp]
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../assets/combined_scientific_named_list.txt'

# %%
#function get name
def get_bird_code(bird):
    bird = bird.replace('_', ' ').capitalize()
    code = df[df.SCI_NAME == bird].SPECIES_CODE.values[0]
    return code

# %%
def copy_audio():
    for bird in bird_list:
        if bird in all_audio:
        
            src = xc_audio + bird
            dst = dest_audio + bird
            base = '/datasets/xeno_canto/'
        
            if not '491_dataset' in os.listdir(base):
                os.mkdir(base + '491_dataset')
        
            if not bird in os.listdir(dest_audio):
                os.mkdir(dest_audio + bird)
        
            #copy file form audio to 491_dataset
            os.system('cp {src} {dest}'.format(src = src, dest = dst))
        
            #change folder name
            code = get_bird_code(bird)
            rename = dest_audio + code
            os.system('mv {dest} {rdest}'.format(dest = dst, rdest = rename))

# %%
#Create metadata
output_list = []
for bird in bird_list:
        if bird in all_meta:
            for json_file in os.listdir(xc_metadata + bird):
                
                with open(xc_metadata + bird + '/' + json_file, "rb") as infile:
                    load_file = json.load(infile)
                    rec_dict = load_file['recordings']
            
                for elem in rec_dict:
                    elem['primary_label'] = get_bird_code(bird)
                    elem['secondary_label'] = elem['also']
                    elem['latitude']= elem['lat']
                    elem['longitude']= elem['lng']
                    elem['scientific_name'] = elem['gen'] + ' ' + elem['sp']
                    elem['common_name'] = elem['en']
                    idd = elem['id'] #not include
                    file = 'XC{ids}.ogg'.format(ids = idd) #not include
                    elem['filename'] = bird + '/' + file
                    del elem['gen']
                    del elem['sp']
                    del elem['ssp']
                    del elem['cnt']
                    del elem['loc']
                    del elem['rmk']
                    del elem['also']
                    del elem['en']
                    del elem['lat']
                    del elem['lng']
                    output_list.append(elem)

# %%
create_file(output_list, '../../dataset/metadata/metadata.csv')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_37038/3542550925.py in <module>
# ----> 1 create_file(output_list, '../../dataset/metadata/metadata.csv')
#
# /tmp/ipykernel_37038/3706505665.py in create_file(lis, path)
#       2     df = pd.DataFrame()
#       3     for file in lis:
# ----> 4         df = df.append(file, ignore_index=True)
#       5     df.drop(columns = ['id', 'rec', 'file', 'file-name', 'sono',
#       6                    'lic', 'uploaded', 'bird-seen', 'playback-used', 'alt', 'length'])
#
# ~/.conda/envs/ast_env/lib/python3.9/site-packages/pandas/core/frame.py in append(self, other, ignore_index, verify_integrity, sort)
#    8963             to_concat = [self, other]
#    8964         return (
# -> 8965             concat(
#    8966                 to_concat,
#    8967                 ignore_index=ignore_index,
#
# ~/.conda/envs/ast_env/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.conda/envs/ast_env/lib/python3.9/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     305     )
#     306
# --> 307     return op.get_result()
#     308
#     309
#
# ~/.conda/envs/ast_env/lib/python3.9/site-packages/pandas/core/reshape/concat.py in get_result(self)
#     530                 mgrs_indexers.append((obj._mgr, indexers))
#     531
# --> 532             new_data = concatenate_managers(
#     533                 mgrs_indexers, self.new_axes, concat_axis=self.bm_axis, copy=self.copy
#     534             )
#
# ~/.conda/envs/ast_env/lib/python3.9/site-packages/pandas/core/internals/concat.py in concatenate_managers(mgrs_indexers, axes, concat_axis, copy)
#     214                 #  we can use np.concatenate, which is more performant
#     215                 #  than concat_compat
# --> 216                 values = np.concatenate(vals, axis=blk.ndim - 1)
#     217             else:
#     218                 # TODO(EA2D): special-casing not needed with 2D EAs
#
# <__array_function__ internals> in concatenate(*args, **kwargs)
#
# KeyboardInterrupt:

# %%
output_list[0]
# Out:
# {'id': '693048',
#  'rec': 'Irish Wildlife Sounds',
#  'alt': '50',
#  'type': 'flight call',
#  'url': '//xeno-canto.org/693048',
#  'file': 'https://xeno-canto.org/693048/download',
#  'file-name': 'XC693048-Redpoll sp_Flight Call_Lissagriffin_291021_B.mp3',
#  'sono': {'small': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-small.png',
#   'med': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-med.png',
#   'large': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-large.png',
#   'full': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-full.png'},
#  'lic': '//creativecommons.org/licenses/by-nc-nd/4.0/',
#  'q': 'A',
#  'length': '0:20',
#  'time': '08:00',
#  'date': '2021-10-29',
#  'uploaded': '2021-12-25',
#  'bird-seen': 'no',
#  'playback-used': 'no',
#  'primary_label': 'lesred1',
#  'secondary_label': [''],
#  'latitude': '51.4812',
#  'longitude': '-9.7785',
#  'scientific_name': 'Acanthis cabaret',
#  'common_name': 'Lesser Redpoll',
#  'filename': 'acanthis_cabaret/XC693048.ogg'}

# %%
"""
test = [{'id': '693048',
 'rec': 'Irish Wildlife Sounds',
 'alt': '50',
 'type': 'flight call',
 'url': '//xeno-canto.org/693048',
 'file': 'https://xeno-canto.org/693048/download',
 'file-name': 'XC693048-Redpoll sp_Flight Call_Lissagriffin_291021_B.mp3',
 'sono': {'small': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-small.png',
  'med': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-med.png',
  'large': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-large.png',
  'full': '//xeno-canto.org/sounds/uploaded/PAEQEUHPFQ/ffts/XC693048-full.png'},
 'lic': '//creativecommons.org/licenses/by-nc-nd/4.0/',
 'q': 'A',
 'length': '0:20',
 'time': '08:00',
 'date': '2021-10-29',
 'uploaded': '2021-12-25',
 'bird-seen': 'no',
 'playback-used': 'no',
 'primary_label': 'lesred1',
 'secondary_label': [''],
 'latitude': '51.4812',
 'longitude': '-9.7785',
 'scientific_name': 'Acanthis cabaret',
 'common_name': 'Lesser Redpoll',
 'filename': 'acanthis_cabaret/XC693048.ogg'}]
 """
df = pd.DataFrame.from_dict(output_list)
df
# Out:
#             id                    rec  alt  \
# 0       693048  Irish Wildlife Sounds   50
# 1       692820  Irish Wildlife Sounds   50
# 2       692819  Irish Wildlife Sounds   50
# 3       692818  Irish Wildlife Sounds   50
# 4       692817  Irish Wildlife Sounds   50
# ...        ...                    ...  ...
# 271748  321186                david m  160
# 271749  296869                david m  150
# 271750  208193                david m   80
# 271751  208191                david m   80
# 271752  134665       Albert Lastukhin   90
#
#                                          type                      url  \
# 0                                 flight call  //xeno-canto.org/693048
# 1                                 flight call  //xeno-canto.org/692820
# 2                                 flight call  //xeno-canto.org/692819
# 3                                 flight call  //xeno-canto.org/692818
# 4                                 flight call  //xeno-canto.org/692817
# ...                                       ...                      ...
# 271748                             alarm call  //xeno-canto.org/321186
# 271749                            flight call  //xeno-canto.org/296869
# 271750                                   call  //xeno-canto.org/208193
# 271751                                   call  //xeno-canto.org/208191
# 271752  alarm call, female, flight call, male  //xeno-canto.org/134665
#
#                                           file  \
# 0       https://xeno-canto.org/693048/download
# 1       https://xeno-canto.org/692820/download
# 2       https://xeno-canto.org/692819/download
# 3       https://xeno-canto.org/692818/download
# 4       https://xeno-canto.org/692817/download
# ...                                        ...
# 271748  https://xeno-canto.org/321186/download
# 271749  https://xeno-canto.org/296869/download
# 271750  https://xeno-canto.org/208193/download
# 271751  https://xeno-canto.org/208191/download
# 271752  https://xeno-canto.org/134665/download
#
#                                                 file-name  \
# 0       XC693048-Redpoll sp_Flight Call_Lissagriffin_2...
# 1       XC692820-Lesser Redpoll_Flight Call_Derryad_23...
# 2       XC692819-Lesser Redpoll_Flight Call_Derryad_23...
# 3       XC692818-Lesser Redpoll_Flight Call_Derryad_23...
# 4       XC692817-Lesser Redpoll_Flight Call_Derryad_23...
# ...                                                   ...
# 271748                         XC321186-ZOOM0117_Tr12.mp3
# 271749                                   XC296869-T13.mp3
# 271750                                   XC208193-T10.mp3
# 271751                                   XC208191-T09.mp3
# 271752  XC134665-8018_ 19.05.2013, Красный мост, Марий...
#
#                                                      sono  \
# 0       {'small': '//xeno-canto.org/sounds/uploaded/PA...
# 1       {'small': '//xeno-canto.org/sounds/uploaded/PA...
# 2       {'small': '//xeno-canto.org/sounds/uploaded/PA...
# 3       {'small': '//xeno-canto.org/sounds/uploaded/PA...
# 4       {'small': '//xeno-canto.org/sounds/uploaded/PA...
# ...                                                   ...
# 271748  {'small': '//xeno-canto.org/sounds/uploaded/BT...
# 271749  {'small': '//xeno-canto.org/sounds/uploaded/BT...
# 271750  {'small': '//xeno-canto.org/sounds/uploaded/BT...
# 271751  {'small': '//xeno-canto.org/sounds/uploaded/BT...
# 271752  {'small': '//xeno-canto.org/sounds/uploaded/LE...
#
#                                                  lic  q  ...    uploaded  \
# 0       //creativecommons.org/licenses/by-nc-nd/4.0/  A  ...  2021-12-25
# 1       //creativecommons.org/licenses/by-nc-sa/4.0/  A  ...  2021-12-25
# 2       //creativecommons.org/licenses/by-nc-sa/4.0/  A  ...  2021-12-25
# 3       //creativecommons.org/licenses/by-nc-sa/4.0/  A  ...  2021-12-25
# 4       //creativecommons.org/licenses/by-nc-sa/4.0/  A  ...  2021-12-25
# ...                                              ... ..  ...         ...
# 271748  //creativecommons.org/licenses/by-nc-nd/4.0/  E  ...  2016-06-12
# 271749  //creativecommons.org/licenses/by-nc-nd/4.0/  E  ...  2015-12-25
# 271750  //creativecommons.org/licenses/by-nc-nd/4.0/  E  ...  2014-12-28
# 271751  //creativecommons.org/licenses/by-nc-nd/4.0/  E  ...  2014-12-28
# 271752  //creativecommons.org/licenses/by-nc-sa/3.0/  E  ...  2013-05-23
#
#        bird-seen playback-used primary_label  \
# 0             no            no       lesred1
# 1            yes            no       lesred1
# 2            yes            no       lesred1
# 3            yes            no       lesred1
# 4            yes            no       lesred1
# ...          ...           ...           ...
# 271748       yes            no        norlap
# 271749       yes            no        norlap
# 271750       yes            no        norlap
# 271751       yes            no        norlap
# 271752       yes            no        norlap
#
#                            secondary_label latitude longitude  \
# 0                                       []  51.4812   -9.7785
# 1                                       []  53.7276   -7.7933
# 2                                       []  53.7276   -7.7933
# 3                                       []  53.7276   -7.7933
# 4                                       []  53.7276   -7.7933
# ...                                    ...      ...       ...
# 271748  [Alauda arvensis, Sylvia communis]  54.1359   -0.5537
# 271749                                  []  54.1338   -0.5523
# 271750                                  []    54.12   -0.5445
# 271751                                  []    54.12   -0.5445
# 271752                         [Crex crex]  56.5655   47.1698
#
#           scientific_name       common_name                        filename
# 0        Acanthis cabaret    Lesser Redpoll   acanthis_cabaret/XC693048.ogg
# 1        Acanthis cabaret    Lesser Redpoll   acanthis_cabaret/XC692820.ogg
# 2        Acanthis cabaret    Lesser Redpoll   acanthis_cabaret/XC692819.ogg
# 3        Acanthis cabaret    Lesser Redpoll   acanthis_cabaret/XC692818.ogg
# 4        Acanthis cabaret    Lesser Redpoll   acanthis_cabaret/XC692817.ogg
# ...                   ...               ...                             ...
# 271748  Vanellus vanellus  Northern Lapwing  vanellus_vanellus/XC321186.ogg
# 271749  Vanellus vanellus  Northern Lapwing  vanellus_vanellus/XC296869.ogg
# 271750  Vanellus vanellus  Northern Lapwing  vanellus_vanellus/XC208193.ogg
# 271751  Vanellus vanellus  Northern Lapwing  vanellus_vanellus/XC208191.ogg
# 271752  Vanellus vanellus  Northern Lapwing  vanellus_vanellus/XC134665.ogg
#
# [271753 rows x 23 columns]

# %%
df.columns
# Out:
# Index(['primary_label', 'secondary_label', 'type', 'latitude', 'longitude',
#        'scientific_name', 'common_name', 'time', 'url', 'filename', 'q'],
#       dtype='object')

# %%
df.drop(columns = ['id', 'rec', 'file', 'file-name', 'sono',
                   'lic', 'uploaded', 'bird-seen', 'playback-used', 'alt', 'length'])
df = df[['primary_label', 'secondary_label', 'type', 'latitude', 'longitude', 'scientific_name', 'common_name',
            'time', 'url', 'filename', 'q']]
    
df.to_csv('../../dataset/metadata/metadata.csv', index = False)

# %%
if __name__ == '__main__':    #copy_audio()
    meta_path = '../../dataset/metadata/'
    output_list = copy_metadata()
    create_file(ouput_list, meta_path)
